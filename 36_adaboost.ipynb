# %%
import pandas as pd
import numpy as np
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.DataFrame()

# %%
df['X1'] = [1,2,3,4,5,6,6,7,9,9]
df['X2'] = [5,3,6,3,6,3,7,9,7,1]
df['label'] = [1,1,0,1,0,0,0,1,0,1]

# %%
df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 3   4   3      1      0.1
# 4   5   6      0      0.1
# 5   6   3      0      0.1
# 6   6   7      0      0.1
# 7   7   9      1      0.1
# 8   9   7      0      0.1
# 9   9   1      1      0.1

# %%
import seaborn as sns
sns.scatterplot(x=df['X1'], y=df['X2'], hue = df['label'])
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
df['weights'] = 1/df.shape[0]

# %%
df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 3   4   3      1      0.1
# 4   5   6      0      0.1
# 5   6   3      0      0.1
# 6   6   7      0      0.1
# 7   7   9      1      0.1
# 8   9   7      0      0.1
# 9   9   1      1      0.1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt1 = DecisionTreeClassifier(max_depth = 1)

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,2].values

# %%
y
# Out:
# array([1, 1, 0, 1, 0, 0, 0, 1, 0, 1])

# %%
# step 2- Train 1st model

dt1.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 5.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X,y,clf = dt1, legend = 2)
# Out:
# <Axes: >

# %%
df['y_pred'] = dt1.predict(X)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred
# 0   1   5      1      0.1       1
# 1   2   3      1      0.1       1
# 2   3   6      0      0.1       0
# 3   4   3      1      0.1       1
# 4   5   6      0      0.1       0
# 5   6   3      0      0.1       1
# 6   6   7      0      0.1       0
# 7   7   9      1      0.1       0
# 8   9   7      0      0.1       0
# 9   9   1      1      0.1       1

# %%
def calculate_model_weight(error):
    return 0.5*np.log((1 - error)/error)

# %%
# step 3 - Calculate model weight

alpha1 = calculate_model_weight(0.2)
alpha1
# Out:
# np.float64(0.6931471805599453)

# %%
# Step 4 - Update weights

def update_row_weights(row, alpha =0.693):
    if row['label'] == row['y_pred']: 
        return row['weights'] * np.exp(-alpha)
    else:
        return row['weights'] * np.exp(alpha)

# %%
df['updated_weights'] = df.apply(update_row_weights, axis = 1)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 0   1   5      1      0.1       1         0.050007
# 1   2   3      1      0.1       1         0.050007
# 2   3   6      0      0.1       0         0.050007
# 3   4   3      1      0.1       1         0.050007
# 4   5   6      0      0.1       0         0.050007
# 5   6   3      0      0.1       1         0.199971
# 6   6   7      0      0.1       0         0.050007
# 7   7   9      1      0.1       0         0.199971
# 8   9   7      0      0.1       0         0.050007
# 9   9   1      1      0.1       1         0.050007

# %%
df['updated_weights'].sum()
# Out:
# np.float64(0.8000000086648471)

# %%
df['normalized_weights'] = df['updated_weights']/df['updated_weights'].sum()

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  nomalized_weights  \
# 0   1   5      1      0.1       1         0.050007           0.062509
# 1   2   3      1      0.1       1         0.050007           0.062509
# 2   3   6      0      0.1       0         0.050007           0.062509
# 3   4   3      1      0.1       1         0.050007           0.062509
# 4   5   6      0      0.1       0         0.050007           0.062509
# 5   6   3      0      0.1       1         0.199971           0.249963
# 6   6   7      0      0.1       0         0.050007           0.062509
# 7   7   9      1      0.1       0         0.199971           0.249963
# 8   9   7      0      0.1       0         0.050007           0.062509
# 9   9   1      1      0.1       1         0.050007           0.062509
#
#    normalized_weights
# 0            0.062509
# 1            0.062509
# 2            0.062509
# 3            0.062509
# 4            0.062509
# 5            0.249963
# 6            0.062509
# 7            0.249963
# 8            0.062509
# 9            0.062509

# %%
df['normalized_weights'].sum()
# Out:
# np.float64(0.9999999999999998)

# %%
df.drop('nomalized_weights', axis = 1, inplace = True)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights
# 0   1   5      1      0.1       1         0.050007            0.062509
# 1   2   3      1      0.1       1         0.050007            0.062509
# 2   3   6      0      0.1       0         0.050007            0.062509
# 3   4   3      1      0.1       1         0.050007            0.062509
# 4   5   6      0      0.1       0         0.050007            0.062509
# 5   6   3      0      0.1       1         0.199971            0.249963
# 6   6   7      0      0.1       0         0.050007            0.062509
# 7   7   9      1      0.1       0         0.199971            0.249963
# 8   9   7      0      0.1       0         0.050007            0.062509
# 9   9   1      1      0.1       1         0.050007            0.062509

# %%
df['cumsum_upper'] = np.cumsum(df['normalized_weights'])

# %%
df['cumsum_lower'] = df['cumsum_upper'] - df['normalized_weights']

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights  \
# 0   1   5      1      0.1       1         0.050007            0.062509
# 1   2   3      1      0.1       1         0.050007            0.062509
# 2   3   6      0      0.1       0         0.050007            0.062509
# 3   4   3      1      0.1       1         0.050007            0.062509
# 4   5   6      0      0.1       0         0.050007            0.062509
# 5   6   3      0      0.1       1         0.199971            0.249963
# 6   6   7      0      0.1       0         0.050007            0.062509
# 7   7   9      1      0.1       0         0.199971            0.249963
# 8   9   7      0      0.1       0         0.050007            0.062509
# 9   9   1      1      0.1       1         0.050007            0.062509
#
#    cumsum_upper  cumsum_lower
# 0      0.062509      0.000000
# 1      0.125018      0.062509
# 2      0.187528      0.125018
# 3      0.250037      0.187528
# 4      0.312546      0.250037
# 5      0.562509      0.312546
# 6      0.625018      0.562509
# 7      0.874982      0.625018
# 8      0.937491      0.874982
# 9      1.000000      0.937491

# %%
def create_new_dataset(df):
    indices = []
    for i in range(df.shape[0]):
        a = np.random.random()
        for index, row in df.iterrows():
            if row['cumsum_upper'] > a and a > row['cumsum_lower']:
                indices.append(index)
    return indices

# %%
index_values = create_new_dataset(df)

# %%
index_values
# Out:
# [4, 5, 3, 7, 7, 4, 1, 5, 3, 7]

# %%
second_df = df.iloc[index_values, [0,1,2,3]]

# %%
second_df
# Out:
#    X1  X2  label  weights
# 4   5   6      0      0.1
# 5   6   3      0      0.1
# 3   4   3      1      0.1
# 7   7   9      1      0.1
# 7   7   9      1      0.1
# 4   5   6      0      0.1
# 1   2   3      1      0.1
# 5   6   3      0      0.1
# 3   4   3      1      0.1
# 7   7   9      1      0.1

# %%
dt2 = DecisionTreeClassifier(max_depth = 1)

# %%
X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values

# %%
dt2.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(dt2)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 4.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X,y, clf = dt2, legend = 2)
# Out:
# <Axes: >

# %%
second_df['y_pred'] = dt2.predict(X)

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred
# 4   5   6      0      0.1       0
# 5   6   3      0      0.1       0
# 3   4   3      1      0.1       1
# 7   7   9      1      0.1       0
# 7   7   9      1      0.1       0
# 4   5   6      0      0.1       0
# 1   2   3      1      0.1       1
# 5   6   3      0      0.1       0
# 3   4   3      1      0.1       1
# 7   7   9      1      0.1       0

# %%
alpha2 = calculate_model_weight(0.1)

# %%
alpha2
# Out:
# np.float64(1.0986122886681098)

# %%
# Step 4 - Update weights
def update_row_weights(row,alpha=1.09):
  if row['label'] == row['y_pred']:
    return row['weights'] * np.exp(-alpha)
  else:
    return row['weights'] * np.exp(alpha)

# %%
second_df['updated_weights'] = second_df.apply(update_row_weights,axis=1)

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 4   5   6      0      0.1       0         0.033622
# 5   6   3      0      0.1       0         0.033622
# 3   4   3      1      0.1       1         0.033622
# 7   7   9      1      0.1       0         0.297427
# 7   7   9      1      0.1       0         0.297427
# 4   5   6      0      0.1       0         0.033622
# 1   2   3      1      0.1       1         0.033622
# 5   6   3      0      0.1       0         0.033622
# 3   4   3      1      0.1       1         0.033622
# 7   7   9      1      0.1       0         0.297427

# %%
second_df['nomalized_weights'] = second_df['updated_weights']/second_df['updated_weights'].sum()

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  nomalized_weights
# 4   5   6      0      0.1       0         0.033622           0.029816
# 5   6   3      0      0.1       0         0.033622           0.029816
# 3   4   3      1      0.1       1         0.033622           0.029816
# 7   7   9      1      0.1       0         0.297427           0.263762
# 7   7   9      1      0.1       0         0.297427           0.263762
# 4   5   6      0      0.1       0         0.033622           0.029816
# 1   2   3      1      0.1       1         0.033622           0.029816
# 5   6   3      0      0.1       0         0.033622           0.029816
# 3   4   3      1      0.1       1         0.033622           0.029816
# 7   7   9      1      0.1       0         0.297427           0.263762

# %%
second_df['nomalized_weights'].sum()
# Out:
# np.float64(1.0)

# %%
second_df['cumsum_upper'] = np.cumsum(second_df['nomalized_weights'])

# %%
second_df['cumsum_lower'] = second_df['cumsum_upper'] - second_df['nomalized_weights']

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  nomalized_weights  \
# 4   5   6      0      0.1       0         0.033622           0.029816
# 5   6   3      0      0.1       0         0.033622           0.029816
# 3   4   3      1      0.1       1         0.033622           0.029816
# 7   7   9      1      0.1       0         0.297427           0.263762
# 7   7   9      1      0.1       0         0.297427           0.263762
# 4   5   6      0      0.1       0         0.033622           0.029816
# 1   2   3      1      0.1       1         0.033622           0.029816
# 5   6   3      0      0.1       0         0.033622           0.029816
# 3   4   3      1      0.1       1         0.033622           0.029816
# 7   7   9      1      0.1       0         0.297427           0.263762
#
#    cumsum_upper  cumsum_lower
# 4      0.029816      0.000000
# 5      0.059632      0.029816
# 3      0.089448      0.059632
# 7      0.353211      0.089448
# 7      0.616973      0.353211
# 4      0.646789      0.616973
# 1      0.676605      0.646789
# 5      0.706421      0.676605
# 3      0.736238      0.706421
# 7      1.000000      0.736238

# %%
index_values = create_new_dataset(second_df)

# %%
third_df = second_df.iloc[index_values,[0,1,2,3]]

# %%
third_df
# Out:
#    X1  X2  label  weights
# 5   6   3      0      0.1
# 5   6   3      0      0.1
# 5   6   3      0      0.1
# 5   6   3      0      0.1
# 7   7   9      1      0.1
# 5   6   3      0      0.1
# 4   5   6      0      0.1
# 5   6   3      0      0.1
# 5   6   3      0      0.1
# 5   6   3      0      0.1

# %%
dt3 = DecisionTreeClassifier(max_depth=1)

X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values

dt3.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_decision_regions(X, y, clf=dt3, legend=2)
# Out:
# <Axes: >

# %%
third_df['y_pred'] = dt3.predict(X)

# %%
third_df
# Out:
#    X1  X2  label  weights  y_pred
# 5   6   3      0      0.1       0
# 5   6   3      0      0.1       0
# 5   6   3      0      0.1       0
# 5   6   3      0      0.1       1
# 7   7   9      1      0.1       1
# 5   6   3      0      0.1       0
# 4   5   6      0      0.1       0
# 5   6   3      0      0.1       0
# 5   6   3      0      0.1       0
# 5   6   3      0      0.1       1

# %%
alpha3 = calculate_model_weight(0.7)
alpha3
# Out:
# np.float64(-0.4236489301936017)

# %%
print(alpha1,alpha2,alpha3)
# Out:
# 0.6931471805599453 1.0986122886681098 -0.4236489301936017

# %% [markdown]
# ## Prediction

# %%
query = np.array([1,5]).reshape(1,2)
dt1.predict(query)
# Out:
# array([1])

# %%
dt2.predict(query)
# Out:
# array([1])

# %%
dt3.predict(query)
# Out:
# array([0])

# %%
alpha1*1 + alpha2*(1) + alpha3*(1)
# Out:
# np.float64(1.3681105390344532)

# %%
np.sign(1.09)
# Out:
# np.float64(1.0)

# %%
query = np.array([9,9]).reshape(1,2)
dt1.predict(query)
# Out:
# array([0])

# %%
dt2.predict(query)
# Out:
# array([0])

# %%
dt3.predict(query)
# Out:
# array([1])

# %%
alpha1*(1) + alpha2*(-1) + alpha3*(-1)
# Out:
# np.float64(0.01818382208543723)

# %%
np.sign(-0.25)
# Out:
# np.float64(-1.0)
